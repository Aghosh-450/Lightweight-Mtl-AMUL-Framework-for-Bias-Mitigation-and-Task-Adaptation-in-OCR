# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

zip_file_path = '/content/drive/MyDrive/Apu__Ashis_Protptype/OMNIGLOT FinalM.zip'
extract_dir = './'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents to the target directory
    zip_ref.extractall(extract_dir)

print(f"Files extracted to: {extract_dir}")

# %%
# !pip install easyfsl
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import Omniglot
from torchvision.models import resnet18
from tqdm import tqdm

from easyfsl.samplers import TaskSampler
from easyfsl.utils import plot_images, sliding_average

# %%
import os
import random
from collections import defaultdict
from PIL import Image, ImageOps
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

class PrototypicalOmniglotDataset(Dataset):
    def __init__(self, root, num_classes=1623, n_shot=5, n_query=10, transform=None):
        self.root = root
        self.num_classes = num_classes
        self.n_shot = n_shot
        self.n_query = n_query
        self.transform = transform
        self.samples_by_label = defaultdict(list)
        self.all_imgs = {}
        self.classes = []

        # Common image file extensions
        image_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff', '.webp']

        # Organize data into classes and image paths
        for alphabet in os.listdir(self.root):
            alphabet_path = os.path.join(self.root, alphabet)
            if not os.path.isdir(alphabet_path):
                continue

            for char_class in os.listdir(alphabet_path):
                char_class_path = os.path.join(alphabet_path, char_class)

                # Skip if the entry is not a directory
                if not os.path.isdir(char_class_path):
                    continue

                all_images = []
                for img_name in os.listdir(char_class_path):
                    img_path = os.path.join(char_class_path, img_name)

                    # Check if it's a file with a recognized image extension
                    if os.path.isfile(img_path) and any(img_name.lower().endswith(ext) for ext in image_extensions):
                        all_images.append(img_path)

                if all_images:
                    char_class_name = f"{alphabet}_{char_class}"
                    self.samples_by_label[char_class_name] = list(range(len(all_images)))
                    self.all_imgs[char_class_name] = all_images
                    self.classes.append(char_class_name)

    def transform_image(self, raw_img):
        img = ImageOps.invert(raw_img)
        if self.transform is not None:
            img = self.transform(img)
        return img

    def __getitem__(self, index):
        selected_classes = random.sample(self.classes, self.num_classes)
        class_indices = [self.samples_by_label[each_cls] for each_cls in selected_classes]

        support_set = []
        query_set = []
        label_id = 0
        qs=[]
        for idx_set in class_indices:
            # Creating support set
            selected_support = random.sample(idx_set, self.n_shot)
            support_images = [self.transform_image(Image.open(self.all_imgs[selected_classes[label_id]][each]).convert('L')) for each in selected_support]

            # Creating query set
            selected_query = random.sample(idx_set, self.n_query)
            query_images = [self.transform_image(Image.open(self.all_imgs[selected_classes[label_id]][each]).convert('L')) for each in selected_query]
            support_set.append((support_images, [label_id for _ in range(self.n_shot)]))
            # print("aaaaaaaaaa",label_id)
            query_set.append((query_images,  [label_id for _ in range(self.n_query)]))

            label_id += 1
            # qs= [item for item in a for _ in range(self.n_query)]
        return support_set, query_set

    def __len__(self):
        return 10

# Set up the transformations
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
    transforms.ToTensor(),
])

# Set up the SiameseOmniglotDataset
# Training == evaluation
root_path = '/content/OMNIGLOT/Train'
num_classes = 5  # Set the desired number of classes per episode
n_shot = 5
n_query = 10

PrototypicalOmniglotDatasetLoader = PrototypicalOmniglotDataset(root=root_path, num_classes=num_classes, n_shot=n_shot, n_query=n_query, transform=transform)

# %%
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(num_output_channels=3),  # Convert to 3-channel grayscale
    transforms.ToTensor(),
])


# Set up the PrototypicalOmniglotDatasetLoader
root_path ='/content/OMNIGLOT/Test'# '/path/to/omniglot_dataset'
num_classes = 3
n_shot = 2
n_query = 3

dataset = PrototypicalOmniglotDataset(root=root_path, num_classes=num_classes, n_shot=n_shot, n_query=n_query, transform=transform)
dataloader = DataLoader(dataset, batch_size=1, shuffle=False)
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have a PrototypicalNetwork model
# model = PrototypicalNetwork(num_classes=num_classes).to(device)

# Set the model to evaluation mode
# model.eval()

# Choose an episode to visualize
episode_index = 10  # Change this to the desired episode index

# Get support set and query set for the chosen episode
support_set, query_set = dataset[episode_index]

# Visualize support set
for i, (support_images, lbl) in enumerate(support_set):
    for j, img in enumerate(support_images):
        plt.subplot(len(support_set), len(support_images), i * len(support_images) + j + 1)
        plt.imshow(img[0], cmap='gray')  # Assuming the image is grayscale
        plt.axis('off')
        plt.title(f'Support {i + 1}-{j + 1}{lbl[j]}')

plt.suptitle('Support Set')
plt.show()

# Visualize query set
for i, (query_images, ll) in enumerate(query_set):
    for j, img in enumerate(query_images):
        plt.subplot(len(query_set), len(query_images), i * len(query_images) + j + 1)
        plt.imshow(img[0], cmap='gray')  # Assuming the image is grayscale
        plt.axis('off')
        plt.title(f'Query {i + 1}-{ll[j]}')

plt.suptitle('Query Set')
plt.show()

# %%
import torch
import torch.nn as nn

class PrototypicalNetworks3(nn.Module):
    def __init__(self, backbone: nn.Module):
        super(PrototypicalNetworks3, self).__init__()
        self.backbone = backbone

    def forward(
        self,
        support_images,
        support_labels,
        query_images: torch.Tensor,
    ) -> torch.Tensor:
        """
        Predict query labels using labeled support images.
        """
        num_classes=len(list(support_labels))
        prototypes = []
        for class_label in range(num_classes):
            # print(type(support_images[class_label]),torch.cat(support_images[class_label].shape)
            support_images_eachclass=(support_images[class_label])
            class_features = self.backbone(support_images_eachclass.to(device))  # Select features for the current class
            class_prototype = class_features.mean(dim=0)  # Compute the mean along the batch dimension
            prototypes.append(class_prototype)
        prototypes = torch.stack(prototypes)



        query_features = self.backbone(query_images)

        # Compute the distance between query features and prototypes
        distances = torch.cdist(query_features, prototypes)

        return -distances

# %%
import csv

def write_loss_to_csv(dataa, csv_filename='losses.csv'):
    """
    Write episode number and loss to a CSV file.

    Parameters:
    - episode_losses (list): List containing losses for each episode.
    - csv_filename (str): Name of the CSV file to be created.

    Returns:
    None
    """
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([dataa])  # Writing header

        # for episode, loss in enumerate(episode_losses, start=1):
        #     writer.writerow([episode, loss])

# Example Usage:
# Call this function passing your 'episode_losses' list
# and optionally specify the CSV filename.
write_loss_to_csv("hgfdfghj",csv_filename='losses.csv')

# %%
import torch
import torch.nn as nn
import torch.hub

# Define a modified version of DenseNet169 with dropout after each convolutional layer
class DenseNet169WithDropout(nn.Module):
    def __init__(self,modell, pretrained=False, dr=0.4):
        super(DenseNet169WithDropout, self).__init__()
        self.densenet169 = torch.hub.load('pytorch/vision:v0.10.0', modell, pretrained=pretrained)
        self.dropout = nn.Dropout(p=dr)  # Dropout with probability 0.5

        # Modify each dense block to include dropout after each convolutional layer
        for name, module in self.densenet169.features.named_children():
            if isinstance(module, nn.Sequential):
                for sub_name, sub_module in module.named_children():
                    if isinstance(sub_module, nn.Conv2d):
                        setattr(module, sub_name, nn.Sequential(sub_module, self.dropout))

    def forward(self, x):
        return self.densenet169(x)

# %%
def update_lr(optimizer):
    for param_group in optimizer.param_groups:
        param_group['lr'] /= 2.0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
from collections import defaultdict
from PIL import Image, ImageOps
import os
import random


transform = transforms.Compose([
    transforms.Resize(72),
    transforms.RandomResizedCrop(64),  # Randomly crop the image and resize to 224x224
    # transforms.RandomHorizontalFlip(),  # Randomly flip the image horizontally
    transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1),  # Randomly adjust brightness, contrast, saturation, and hue
    transforms.RandomAffine(degrees=0, translate=(0, 0), scale=(0.9, 1.1), shear=0),  # Random zoom (scaling)
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),  # Convert PIL Image to PyTorch Tensor
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Normalize the image with ImageNet statistics
])
#background == Training

root_path = '/content/OMNIGLOT/Train'
num_classes = 5
n_shot = 10
n_query = 10
# generate_random_params_trainloader()
print(f"Generated random values - num_classes: {num_classes}, n_shot: {n_shot}, n_query: {n_query}")

dataset = PrototypicalOmniglotDataset(root=root_path, num_classes=num_classes, n_shot=n_shot, n_query=n_query, transform=transform)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

convolutional_network_with_dropout = DenseNet169WithDropout(modell='densenet169',pretrained=False,dr=0.4)

convolutional_network_with_dropout.fc = nn.Flatten()
model = PrototypicalNetworks3(convolutional_network_with_dropout).to(device)  # Assuming you have PrototypicalNetworks defined

total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Total parameters:", total_params)


criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.004)
episode_losses = []
#num_episodes = len(dataset)
#print(num_episodes)
for episode in range(50):

    support_set, query_set = dataset[episode]

    # Convert data to tensors and move to device
    support_set = [(torch.stack(images).to(device), label[0]) for images, label in support_set]
    query_set = [(torch.stack(images).to(device), label) for images, label in query_set]

    # Forward pass
    support_images, support_labels = zip(*support_set)
    query_images, query_labels = zip(*query_set)
    # print(len(support_images),len(support_labels),type(support_images[0]),support_labels,)

    # support_images = torch.cat(support_images)
    # support_labels = torch.tensor(support_labels).to(device)
    query_images = torch.cat(query_images)
    query_labels = torch.tensor(query_labels).to(device)
    query_labels = query_labels.view(-1)
    tskloss = 0
    ta=""
    # print(query_labels)
    for i in range(40):
      model.train()

      classification_scores = model(support_images, support_labels, query_images)
      # print(classification_scores.shape)


      loss = criterion(classification_scores, query_labels)
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

      tskloss+=loss.item()
      if(i==0 or i==39):
        predicted_labels = torch.argmax(classification_scores, dim=1)
        pp=predicted_labels.tolist()
        act=query_labels.tolist()
        cortt=0
        for iii in range(len(pp)):
          if pp[iii] == act[iii]:
              cortt = cortt + 1
        print("Traning accuracy: ",cortt/len(pp))
        ta="Training Accuracy: ,"+str(cortt/len(pp))
      print("    --->>>   episode",episode,"mini_epoch:",i,"  train loss: ",loss.item())

# Calculate the total number of matching values
# total_matching_values = sum(matching_counts)

    episode_losses.append(tskloss)
    num_classes = random.choice([5,10,15,20])  # Random number of classes (e.g., between 3 and 10)
    n_shot = random.randint(1, 15)       # Random number of support examples per class (e.g., between 5 and 15)
    n_query = 20-n_shot
    dataset = PrototypicalOmniglotDataset(root=root_path, num_classes=num_classes, n_shot=n_shot, n_query=n_query, transform=transform)
    print(f"Generated  Tasks - num_classes: {num_classes}, n_shot: {n_shot}, n_query: {n_query}")
    if episode%5==0:
      torch.save(model.state_dict(), folderr+'/modelrdnet_169____'+str(episode)+'.pth')
# Out:
# Generated random values - num_classes: 5, n_shot: 10, n_query: 10
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Total parameters: 14149480
# Traning accuracy:  0.6
#     --->>>   episode 26 mini_epoch: 0   train loss:  1.0132673978805542
#     --->>>   episode 26 mini_epoch: 1   train loss:  1.6257914304733276
#     --->>>   episode 26 mini_epoch: 2   train loss:  1.721142292022705
#     --->>>   episode 26 mini_epoch: 3   train loss:  1.5656388998031616
#     --->>>   episode 26 mini_epoch: 4   train loss:  1.0189504623413086
#     --->>>   episode 26 mini_epoch: 5   train loss:  0.7499938011169434
#     --->>>   episode 26 mini_epoch: 6   train loss:  0.6162534952163696
#     --->>>   episode 26 mini_epoch: 7   train loss:  0.4389217495918274
#     --->>>   episode 26 mini_epoch: 8   train loss:  0.36420172452926636
#     --->>>   episode 26 mini_epoch: 9   train loss:  0.2630855143070221
#     --->>>   episode 26 mini_epoch: 10   train loss:  0.1801314502954483
#     --->>>   episode 26 mini_epoch: 11   train loss:  0.163096085190773
#     --->>>   episode 26 mini_epoch: 12   train loss:  0.12390072643756866
#     --->>>   episode 26 mini_epoch: 13   train loss:  0.0979633703827858
#     --->>>   episode 26 mini_epoch: 14   train loss:  0.07132730633020401
#     --->>>   episode 26 mini_epoch: 15   train loss:  0.07208237051963806
#     --->>>   episode 26 mini_epoch: 16   train loss:  0.07191047817468643
#     --->>>   episode 26 mini_epoch: 17   train loss:  0.0656222328543663
#     --->>>   episode 26 mini_epoch: 18   train loss:  0.050964757800102234
#     --->>>   episode 26 mini_epoch: 19   train loss:  0.019262777641415596
#     --->>>   episode 26 mini_epoch: 20   train loss:  0.03174824267625809
#     --->>>   episode 26 mini_epoch: 21   train loss:  0.015745734795928
#     --->>>   episode 26 mini_epoch: 22   train loss:  0.008378932252526283
#     --->>>   episode 26 mini_epoch: 23   train loss:  0.013813333585858345
#     --->>>   episode 26 mini_epoch: 24   train loss:  0.008660886436700821
# Generated  Tasks - num_classes: 10, n_shot: 11, n_query: 9
# Traning accuracy:  0.2111111111111111
#     --->>>   episode 27 mini_epoch: 0   train loss:  2.613678455352783
#     --->>>   episode 27 mini_epoch: 1   train loss:  2.0154035091400146
#     --->>>   episode 27 mini_epoch: 2   train loss:  2.14603590965271
#     --->>>   episode 27 mini_epoch: 3   train loss:  1.9159798622131348
#     --->>>   episode 27 mini_epoch: 4   train loss:  1.9566594362258911
#     --->>>   episode 27 mini_epoch: 5   train loss:  1.752689242362976
#     --->>>   episode 27 mini_epoch: 6   train loss:  1.601959228515625
#     --->>>   episode 27 mini_epoch: 7   train loss:  1.569021224975586
#     --->>>   episode 27 mini_epoch: 8   train loss:  1.4192867279052734
#     --->>>   episode 27 mini_epoch: 9   train loss:  1.3391684293746948
#     --->>>   episode 27 mini_epoch: 10   train loss:  1.2218295335769653
#     --->>>   episode 27 mini_epoch: 11   train loss:  1.056930661201477
#     --->>>   episode 27 mini_epoch: 12   train loss:  1.057466983795166
#     --->>>   episode 27 mini_epoch: 13   train loss:  0.9296776056289673
#     --->>>   episode 27 mini_epoch: 14   train loss:  0.8406184911727905
#     --->>>   episode 27 mini_epoch: 15   train loss:  0.7553516626358032
#     --->>>   episode 27 mini_epoch: 16   train loss:  0.6544192433357239
#     --->>>   episode 27 mini_epoch: 17   train loss:  0.5654956102371216
#     --->>>   episode 27 mini_epoch: 18   train loss:  0.48828834295272827
#     --->>>   episode 27 mini_epoch: 19   train loss:  0.3772715628147125
#     --->>>   episode 27 mini_epoch: 20   train loss:  0.3764180839061737
#     --->>>   episode 27 mini_epoch: 21   train loss:  0.4061073660850525
#     --->>>   episode 27 mini_epoch: 22   train loss:  0.2854726016521454
#     --->>>   episode 27 mini_epoch: 23   train loss:  0.19775459170341492
#     --->>>   episode 27 mini_epoch: 24   train loss:  0.10948926955461502
# Generated  Tasks - num_classes: 5, n_shot: 10, n_query: 10
# Traning accuracy:  0.48
#     --->>>   episode 28 mini_epoch: 0   train loss:  1.8070379495620728
#     --->>>   episode 28 mini_epoch: 1   train loss:  2.2154123783111572
#     --->>>   episode 28 mini_epoch: 2   train loss:  1.2294175624847412
#     --->>>   episode 28 mini_epoch: 3   train loss:  1.0718573331832886
#     --->>>   episode 28 mini_epoch: 4   train loss:  0.9639989733695984
#     --->>>   episode 28 mini_epoch: 5   train loss:  0.9105137586593628
#     --->>>   episode 28 mini_epoch: 6   train loss:  0.7963210344314575
#     --->>>   episode 28 mini_epoch: 7   train loss:  0.7052056193351746
#     --->>>   episode 28 mini_epoch: 8   train loss:  0.6616725325584412
#     --->>>   episode 28 mini_epoch: 9   train loss:  0.590863049030304
#     --->>>   episode 28 mini_epoch: 10   train loss:  0.5182622075080872
#     --->>>   episode 28 mini_epoch: 11   train loss:  0.45044752955436707
#     --->>>   episode 28 mini_epoch: 12   train loss:  0.36457428336143494
#     --->>>   episode 28 mini_epoch: 13   train loss:  0.3270111382007599
#     --->>>   episode 28 mini_epoch: 14   train loss:  0.27098044753074646
#     --->>>   episode 28 mini_epoch: 15   train loss:  0.19851024448871613
#     --->>>   episode 28 mini_epoch: 16   train loss:  0.1953633427619934
#     --->>>   episode 28 mini_epoch: 17   train loss:  0.1300434172153473
#     --->>>   episode 28 mini_epoch: 18   train loss:  0.1004074364900589
#     --->>>   episode 28 mini_epoch: 19   train loss:  0.06940609961748123
#     --->>>   episode 28 mini_epoch: 20   train loss:  0.06527223438024521
#     --->>>   episode 28 mini_epoch: 21   train loss:  0.024968963116407394
#     --->>>   episode 28 mini_epoch: 22   train loss:  0.01697576977312565
#     --->>>   episode 28 mini_epoch: 23   train loss:  0.025213919579982758
#     --->>>   episode 28 mini_epoch: 24   train loss:  0.016088927164673805
# Generated  Tasks - num_classes: 15, n_shot: 14, n_query: 6
# Traning accuracy:  0.14444444444444443
#     --->>>   episode 29 mini_epoch: 0   train loss:  3.600398540496826
#     --->>>   episode 29 mini_epoch: 1   train loss:  2.535231828689575
#     --->>>   episode 29 mini_epoch: 2   train loss:  2.3206772804260254
#     --->>>   episode 29 mini_epoch: 3   train loss:  2.050936698913574
#     --->>>   episode 29 mini_epoch: 4   train loss:  1.9841686487197876
#     --->>>   episode 29 mini_epoch: 5   train loss:  1.8925609588623047
#     --->>>   episode 29 mini_epoch: 6   train loss:  1.7777369022369385
#     --->>>   episode 29 mini_epoch: 7   train loss:  1.6575220823287964
#     --->>>   episode 29 mini_epoch: 8   train loss:  1.512198567390442
#     --->>>   episode 29 mini_epoch: 9   train loss:  1.3781236410140991
#     --->>>   episode 29 mini_epoch: 10   train loss:  1.2245429754257202
#     --->>>   episode 29 mini_epoch: 11   train loss:  1.081441044807434
#     --->>>   episode 29 mini_epoch: 12   train loss:  0.9627779722213745
#     --->>>   episode 29 mini_epoch: 13   train loss:  0.8519825339317322
#     --->>>   episode 29 mini_epoch: 14   train loss:  0.7872071266174316
#     --->>>   episode 29 mini_epoch: 15   train loss:  0.6535606980323792
#     --->>>   episode 29 mini_epoch: 16   train loss:  0.6252880692481995
#     --->>>   episode 29 mini_epoch: 17   train loss:  0.5109279155731201
#     --->>>   episode 29 mini_epoch: 18   train loss:  0.4321874976158142
#     --->>>   episode 29 mini_epoch: 19   train loss:  0.3502149283885956
#     --->>>   episode 29 mini_epoch: 20   train loss:  0.315390020608902
#     --->>>   episode 29 mini_epoch: 21   train loss:  0.27533501386642456
#     --->>>   episode 29 mini_epoch: 22   train loss:  0.21664229035377502
#     --->>>   episode 29 mini_epoch: 23   train loss:  0.23116302490234375
#     --->>>   episode 29 mini_epoch: 24   train loss:  0.15607458353042603
# Generated  Tasks - num_classes: 20, n_shot: 8, n_query: 12
# Traning accuracy:  0.15416666666666667
#     --->>>   episode 30 mini_epoch: 0   train loss:  4.073268413543701
#     --->>>   episode 30 mini_epoch: 1   train loss:  3.0084750652313232
#     --->>>   episode 30 mini_epoch: 2   train loss:  2.611711263656616
#     --->>>   episode 30 mini_epoch: 3   train loss:  2.5491063594818115
#     --->>>   episode 30 mini_epoch: 4   train loss:  2.47981595993042
#     --->>>   episode 30 mini_epoch: 5   train loss:  2.334338426589966
#     --->>>   episode 30 mini_epoch: 6   train loss:  2.211122989654541
#     --->>>   episode 30 mini_epoch: 7   train loss:  2.116292715072632
#     --->>>   episode 30 mini_epoch: 8   train loss:  2.064122200012207
#     --->>>   episode 30 mini_epoch: 9   train loss:  1.967448353767395
#     --->>>   episode 30 mini_epoch: 10   train loss:  1.8382169008255005
#     --->>>   episode 30 mini_epoch: 11   train loss:  1.8022178411483765
#     --->>>   episode 30 mini_epoch: 12   train loss:  1.7174266576766968
#     --->>>   episode 30 mini_epoch: 13   train loss:  1.6304219961166382
#     --->>>   episode 30 mini_epoch: 14   train loss:  1.5755811929702759
#     --->>>   episode 30 mini_epoch: 15   train loss:  1.4610804319381714
#     --->>>   episode 30 mini_epoch: 16   train loss:  1.4239143133163452
#     --->>>   episode 30 mini_epoch: 17   train loss:  1.317815899848938
#     --->>>   episode 30 mini_epoch: 18   train loss:  1.2702698707580566
#     --->>>   episode 30 mini_epoch: 19   train loss:  1.1898839473724365
#     --->>>   episode 30 mini_epoch: 20   train loss:  1.107797384262085
#     --->>>   episode 30 mini_epoch: 21   train loss:  1.0486093759536743
#     --->>>   episode 30 mini_epoch: 22   train loss:  0.9549187421798706
#     --->>>   episode 30 mini_epoch: 23   train loss:  0.851044774055481
#     --->>>   episode 30 mini_epoch: 24   train loss:  0.7868695855140686
# Generated  Tasks - num_classes: 20, n_shot: 3, n_query: 17
# Traning accuracy:  0.15588235294117647
#     --->>>   episode 31 mini_epoch: 0   train loss:  3.653956174850464
#     --->>>   episode 31 mini_epoch: 1   train loss:  2.5953633785247803
#     --->>>   episode 31 mini_epoch: 2   train loss:  2.397887706756592
#     --->>>   episode 31 mini_epoch: 3   train loss:  2.336723566055298
#     --->>>   episode 31 mini_epoch: 4   train loss:  2.0742809772491455
#     --->>>   episode 31 mini_epoch: 5   train loss:  2.0009472370147705
#     --->>>   episode 31 mini_epoch: 6   train loss:  1.9070484638214111
#     --->>>   episode 31 mini_epoch: 7   train loss:  1.864048719406128
#     --->>>   episode 31 mini_epoch: 8   train loss:  1.90215003490448
#     --->>>   episode 31 mini_epoch: 9   train loss:  1.758537769317627
#     --->>>   episode 31 mini_epoch: 10   train loss:  1.644927978515625
#     --->>>   episode 31 mini_epoch: 11   train loss:  1.5655142068862915
#     --->>>   episode 31 mini_epoch: 12   train loss:  1.505173683166504
#     --->>>   episode 31 mini_epoch: 13   train loss:  1.4591240882873535
#     --->>>   episode 31 mini_epoch: 14   train loss:  1.364133358001709
#     --->>>   episode 31 mini_epoch: 15   train loss:  1.3546757698059082
#     --->>>   episode 31 mini_epoch: 16   train loss:  1.2471750974655151
#     --->>>   episode 31 mini_epoch: 17   train loss:  1.2248919010162354
#     --->>>   episode 31 mini_epoch: 18   train loss:  1.1758884191513062
#     --->>>   episode 31 mini_epoch: 19   train loss:  1.1035289764404297
#     --->>>   episode 31 mini_epoch: 20   train loss:  1.067172646522522
#     --->>>   episode 31 mini_epoch: 21   train loss:  0.9761675000190735
#     --->>>   episode 31 mini_epoch: 22   train loss:  0.9544960260391235
#     --->>>   episode 31 mini_epoch: 23   train loss:  0.9255369901657104
#     --->>>   episode 31 mini_epoch: 24   train loss:  0.8748205900192261
# Generated  Tasks - num_classes: 10, n_shot: 1, n_query: 19
# Traning accuracy:  0.20526315789473684
#     --->>>   episode 32 mini_epoch: 0   train loss:  2.9278109073638916
#     --->>>   episode 32 mini_epoch: 1   train loss:  2.0633976459503174
#     --->>>   episode 32 mini_epoch: 2   train loss:  1.7156437635421753
#     --->>>   episode 32 mini_epoch: 3   train loss:  1.6364755630493164
#     --->>>   episode 32 mini_epoch: 4   train loss:  1.563051700592041
#     --->>>   episode 32 mini_epoch: 5   train loss:  1.3856247663497925
#     --->>>   episode 32 mini_epoch: 6   train loss:  1.3653323650360107
#     --->>>   episode 32 mini_epoch: 7   train loss:  1.29478120803833
#     --->>>   episode 32 mini_epoch: 8   train loss:  1.1458616256713867
#     --->>>   episode 32 mini_epoch: 9   train loss:  1.1722586154937744
#     --->>>   episode 32 mini_epoch: 10   train loss:  1.1070430278778076
#     --->>>   episode 32 mini_epoch: 11   train loss:  0.9104993939399719
#     --->>>   episode 32 mini_epoch: 12   train loss:  0.9462794065475464
#     --->>>   episode 32 mini_epoch: 13   train loss:  0.8441111445426941
#     --->>>   episode 32 mini_epoch: 14   train loss:  0.6873522996902466
#     --->>>   episode 32 mini_epoch: 15   train loss:  0.6773473620414734
#     --->>>   episode 32 mini_epoch: 16   train loss:  0.6286759376525879
#     --->>>   episode 32 mini_epoch: 17   train loss:  0.5750105977058411
#     --->>>   episode 32 mini_epoch: 18   train loss:  0.48892053961753845
#     --->>>   episode 32 mini_epoch: 19   train loss:  0.4178517460823059
#     --->>>   episode 32 mini_epoch: 20   train loss:  0.4592171013355255
#     --->>>   episode 32 mini_epoch: 21   train loss:  0.3393285274505615
#     --->>>   episode 32 mini_epoch: 22   train loss:  0.3233509361743927
#     --->>>   episode 32 mini_epoch: 23   train loss:  0.27745863795280457
#     --->>>   episode 32 mini_epoch: 24   train loss:  0.26213982701301575
# Generated  Tasks - num_classes: 15, n_shot: 7, n_query: 13
# Traning accuracy:  0.08205128205128205
#     --->>>   episode 33 mini_epoch: 0   train loss:  3.0410635471343994
#     --->>>   episode 33 mini_epoch: 1   train loss:  2.444021701812744
#     --->>>   episode 33 mini_epoch: 2   train loss:  2.1037981510162354
#     --->>>   episode 33 mini_epoch: 3   train loss:  1.8861854076385498
#     --->>>   episode 33 mini_epoch: 4   train loss:  1.8307236433029175
#     --->>>   episode 33 mini_epoch: 5   train loss:  1.7659772634506226
#     --->>>   episode 33 mini_epoch: 6   train loss:  1.6475528478622437
#     --->>>   episode 33 mini_epoch: 7   train loss:  1.5763760805130005
#     --->>>   episode 33 mini_epoch: 8   train loss:  1.4108487367630005
#     --->>>   episode 33 mini_epoch: 9   train loss:  1.3964459896087646
#     --->>>   episode 33 mini_epoch: 10   train loss:  1.31916081905365
#     --->>>   episode 33 mini_epoch: 11   train loss:  1.262776255607605
#     --->>>   episode 33 mini_epoch: 12   train loss:  1.119000792503357
#     --->>>   episode 33 mini_epoch: 13   train loss:  1.0738439559936523
#     --->>>   episode 33 mini_epoch: 14   train loss:  1.048865556716919
#     --->>>   episode 33 mini_epoch: 15   train loss:  1.0099645853042603
#     --->>>   episode 33 mini_epoch: 16   train loss:  0.858124852180481
#     --->>>   episode 33 mini_epoch: 17   train loss:  0.8601129055023193
#     --->>>   episode 33 mini_epoch: 18   train loss:  0.8120697140693665
#     --->>>   episode 33 mini_epoch: 19   train loss:  0.6505316495895386
#     --->>>   episode 33 mini_epoch: 20   train loss:  0.6315627098083496
#     --->>>   episode 33 mini_epoch: 21   train loss:  0.5876309275627136
#     --->>>   episode 33 mini_epoch: 22   train loss:  0.4977777302265167
#     --->>>   episode 33 mini_epoch: 23   train loss:  0.46737241744995117
#     --->>>   episode 33 mini_epoch: 24   train loss:  0.42064374685287476
# Generated  Tasks - num_classes: 5, n_shot: 1, n_query: 19
# Traning accuracy:  0.28421052631578947
#     --->>>   episode 34 mini_epoch: 0   train loss:  3.270005464553833
#     --->>>   episode 34 mini_epoch: 1   train loss:  1.6755441427230835
#     --->>>   episode 34 mini_epoch: 2   train loss:  1.3694055080413818
#     --->>>   episode 34 mini_epoch: 3   train loss:  1.1590192317962646
#     --->>>   episode 34 mini_epoch: 4   train loss:  1.170652151107788
#     --->>>   episode 34 mini_epoch: 5   train loss:  0.9113730788230896
#     --->>>   episode 34 mini_epoch: 6   train loss:  0.7896132469177246
#     --->>>   episode 34 mini_epoch: 7   train loss:  0.808135449886322
#     --->>>   episode 34 mini_epoch: 8   train loss:  0.6090704798698425
#     --->>>   episode 34 mini_epoch: 9   train loss:  0.5820494890213013
#     --->>>   episode 34 mini_epoch: 10   train loss:  0.38541513681411743
#     --->>>   episode 34 mini_epoch: 11   train loss:  0.37483808398246765
#     --->>>   episode 34 mini_epoch: 12   train loss:  0.3088710606098175
#     --->>>   episode 34 mini_epoch: 13   train loss:  0.24083328247070312
#     --->>>   episode 34 mini_epoch: 14   train loss:  0.1700703203678131
#     --->>>   episode 34 mini_epoch: 15   train loss:  0.1525479108095169
#     --->>>   episode 34 mini_epoch: 16   train loss:  0.15017148852348328
#     --->>>   episode 34 mini_epoch: 17   train loss:  0.1014869213104248
#     --->>>   episode 34 mini_epoch: 18   train loss:  0.07818618416786194
#     --->>>   episode 34 mini_epoch: 19   train loss:  0.07091512531042099
#     --->>>   episode 34 mini_epoch: 20   train loss:  0.056810956448316574
#     --->>>   episode 34 mini_epoch: 21   train loss:  0.040857549756765366
#     --->>>   episode 34 mini_epoch: 22   train loss:  0.051511023193597794
#     --->>>   episode 34 mini_epoch: 23   train loss:  0.03560929372906685
#     --->>>   episode 34 mini_epoch: 24   train loss:  0.029128853231668472
# Generated  Tasks - num_classes: 5, n_shot: 2, n_query: 18
# Traning accuracy:  0.14444444444444443
#     --->>>   episode 35 mini_epoch: 0   train loss:  2.9133074283599854
#     --->>>   episode 35 mini_epoch: 1   train loss:  1.5047129392623901
#     --->>>   episode 35 mini_epoch: 2   train loss:  1.713797688484192
#     --->>>   episode 35 mini_epoch: 3   train loss:  0.9837074875831604
#     --->>>   episode 35 mini_epoch: 4   train loss:  0.8181218504905701
#     --->>>   episode 35 mini_epoch: 5   train loss:  0.7371188402175903
#     --->>>   episode 35 mini_epoch: 6   train loss:  0.7133318781852722
#     --->>>   episode 35 mini_epoch: 7   train loss:  0.7158404588699341
#     --->>>   episode 35 mini_epoch: 8   train loss:  0.5823729038238525
#     --->>>   episode 35 mini_epoch: 9   train loss:  0.42665207386016846
#     --->>>   episode 35 mini_epoch: 10   train loss:  0.3303177058696747
#     --->>>   episode 35 mini_epoch: 11   train loss:  0.21839496493339539
#     --->>>   episode 35 mini_epoch: 12   train loss:  0.21498434245586395
#     --->>>   episode 35 mini_epoch: 13   train loss:  0.16283340752124786
#     --->>>   episode 35 mini_epoch: 14   train loss:  0.14413325488567352
#     --->>>   episode 35 mini_epoch: 15   train loss:  0.130319282412529
#     --->>>   episode 35 mini_epoch: 16   train loss:  0.14734332263469696
#     --->>>   episode 35 mini_epoch: 17   train loss:  0.07871846109628677
#     --->>>   episode 35 mini_epoch: 18   train loss:  0.06342564523220062
#     --->>>   episode 35 mini_epoch: 19   train loss:  0.08578319847583771
#     --->>>   episode 35 mini_epoch: 20   train loss:  0.038925908505916595
#     --->>>   episode 35 mini_epoch: 21   train loss:  0.03204133361577988
#     --->>>   episode 35 mini_epoch: 22   train loss:  0.03346983715891838
#     --->>>   episode 35 mini_epoch: 23   train loss:  0.01989046297967434
#     --->>>   episode 35 mini_epoch: 24   train loss:  0.03305208310484886
# Generated  Tasks - num_classes: 20, n_shot: 1, n_query: 19
# Traning accuracy:  0.04736842105263158
#     --->>>   episode 36 mini_epoch: 0   train loss:  4.606229305267334
#     --->>>   episode 36 mini_epoch: 1   train loss:  3.2427361011505127
#     --->>>   episode 36 mini_epoch: 2   train loss:  2.903165817260742
#     --->>>   episode 36 mini_epoch: 3   train loss:  2.7254104614257812
#     --->>>   episode 36 mini_epoch: 4   train loss:  2.5663695335388184
#     --->>>   episode 36 mini_epoch: 5   train loss:  2.5150277614593506
#     --->>>   episode 36 mini_epoch: 6   train loss:  2.484466791152954
#     --->>>   episode 36 mini_epoch: 7   train loss:  2.2943825721740723
#     --->>>   episode 36 mini_epoch: 8   train loss:  2.235460042953491
#     --->>>   episode 36 mini_epoch: 9   train loss:  2.0881614685058594
#     --->>>   episode 36 mini_epoch: 10   train loss:  2.0759389400482178
#     --->>>   episode 36 mini_epoch: 11   train loss:  2.0628418922424316
#     --->>>   episode 36 mini_epoch: 12   train loss:  1.8991129398345947
#     --->>>   episode 36 mini_epoch: 13   train loss:  1.861077070236206
#     --->>>   episode 36 mini_epoch: 14   train loss:  1.8281383514404297
#     --->>>   episode 36 mini_epoch: 15   train loss:  1.8737579584121704
#     --->>>   episode 36 mini_epoch: 16   train loss:  1.697101354598999
#     --->>>   episode 36 mini_epoch: 17   train loss:  1.6421103477478027
#     --->>>   episode 36 mini_epoch: 18   train loss:  1.5925602912902832
#     --->>>   episode 36 mini_epoch: 19   train loss:  1.5271379947662354
#     --->>>   episode 36 mini_epoch: 20   train loss:  1.457511067390442
#     --->>>   episode 36 mini_epoch: 21   train loss:  1.4666794538497925
#     --->>>   episode 36 mini_epoch: 22   train loss:  1.413913607597351
#     --->>>   episode 36 mini_epoch: 23   train loss:  1.340451717376709
#     --->>>   episode 36 mini_epoch: 24   train loss:  1.249630093574524
# Generated  Tasks - num_classes: 20, n_shot: 1, n_query: 19
# Traning accuracy:  0.11052631578947368
#     --->>>   episode 37 mini_epoch: 0   train loss:  4.053232192993164
#     --->>>   episode 37 mini_epoch: 1   train loss:  3.2055883407592773
#     --->>>   episode 37 mini_epoch: 2   train loss:  2.403853416442871
#     --->>>   episode 37 mini_epoch: 3   train loss:  2.2866203784942627
#     --->>>   episode 37 mini_epoch: 4   train loss:  2.2593047618865967
#     --->>>   episode 37 mini_epoch: 5   train loss:  2.2320666313171387
#     --->>>   episode 37 mini_epoch: 6   train loss:  2.0682477951049805
#     --->>>   episode 37 mini_epoch: 7   train loss:  2.1277458667755127
#     --->>>   episode 37 mini_epoch: 8   train loss:  2.0261425971984863
#     --->>>   episode 37 mini_epoch: 9   train loss:  1.917479157447815
#     --->>>   episode 37 mini_epoch: 10   train loss:  1.8378602266311646
#     --->>>   episode 37 mini_epoch: 11   train loss:  1.77217435836792
#     --->>>   episode 37 mini_epoch: 12   train loss:  1.8595486879348755
#     --->>>   episode 37 mini_epoch: 13   train loss:  1.7329962253570557
#     --->>>   episode 37 mini_epoch: 14   train loss:  1.7306804656982422
#     --->>>   episode 37 mini_epoch: 15   train loss:  1.6012719869613647
#     --->>>   episode 37 mini_epoch: 16   train loss:  1.5784517526626587
#     --->>>   episode 37 mini_epoch: 17   train loss:  1.52424156665802
#     --->>>   episode 37 mini_epoch: 18   train loss:  1.455181360244751
#     --->>>   episode 37 mini_epoch: 19   train loss:  1.4009926319122314
#     --->>>   episode 37 mini_epoch: 20   train loss:  1.372272253036499
#     --->>>   episode 37 mini_epoch: 21   train loss:  1.3198250532150269
#     --->>>   episode 37 mini_epoch: 22   train loss:  1.3211201429367065
#     --->>>   episode 37 mini_epoch: 23   train loss:  1.2221518754959106
#     --->>>   episode 37 mini_epoch: 24   train loss:  1.2811802625656128
# Generated  Tasks - num_classes: 10, n_shot: 2, n_query: 18
# Traning accuracy:  0.10555555555555556
#     --->>>   episode 38 mini_epoch: 0   train loss:  2.8971362113952637
#     --->>>   episode 38 mini_epoch: 1   train loss:  2.061586618423462
#     --->>>   episode 38 mini_epoch: 2   train loss:  1.530638575553894
#     --->>>   episode 38 mini_epoch: 3   train loss:  1.3145556449890137
#     --->>>   episode 38 mini_epoch: 4   train loss:  1.3735060691833496
#     --->>>   episode 38 mini_epoch: 5   train loss:  1.2919169664382935
#     --->>>   episode 38 mini_epoch: 6   train loss:  1.1688597202301025
#     --->>>   episode 38 mini_epoch: 7   train loss:  1.0473251342773438
#     --->>>   episode 38 mini_epoch: 8   train loss:  1.031165599822998
#     --->>>   episode 38 mini_epoch: 9   train loss:  0.9119059443473816
#     --->>>   episode 38 mini_epoch: 10   train loss:  0.8945926427841187
#     --->>>   episode 38 mini_epoch: 11   train loss:  0.8057280778884888
#     --->>>   episode 38 mini_epoch: 12   train loss:  0.722321629524231
#     --->>>   episode 38 mini_epoch: 13   train loss:  0.6865233778953552
#     --->>>   episode 38 mini_epoch: 14   train loss:  0.6563073396682739
#     --->>>   episode 38 mini_epoch: 15   train loss:  0.5633862614631653
#     --->>>   episode 38 mini_epoch: 16   train loss:  0.47249606251716614
#     --->>>   episode 38 mini_epoch: 17   train loss:  0.45312657952308655
#     --->>>   episode 38 mini_epoch: 18   train loss:  0.48076096177101135
#     --->>>   episode 38 mini_epoch: 19   train loss:  0.39679959416389465
#     --->>>   episode 38 mini_epoch: 20   train loss:  0.3363761603832245
#     --->>>   episode 38 mini_epoch: 21   train loss:  0.3208308219909668
#     --->>>   episode 38 mini_epoch: 22   train loss:  0.2961452901363373
#     --->>>   episode 38 mini_epoch: 23   train loss:  0.28184130787849426
#     --->>>   episode 38 mini_epoch: 24   train loss:  0.283655047416687
# Generated  Tasks - num_classes: 5, n_shot: 15, n_query: 5
# Traning accuracy:  0.52
#     --->>>   episode 39 mini_epoch: 0   train loss:  1.1729087829589844
#     --->>>   episode 39 mini_epoch: 1   train loss:  1.01223886013031
#     --->>>   episode 39 mini_epoch: 2   train loss:  0.7164003849029541
#     --->>>   episode 39 mini_epoch: 3   train loss:  0.5313593149185181
#     --->>>   episode 39 mini_epoch: 4   train loss:  0.3568482995033264
#     --->>>   episode 39 mini_epoch: 5   train loss:  0.23514656722545624
#     --->>>   episode 39 mini_epoch: 6   train loss:  0.11956081539392471
#     --->>>   episode 39 mini_epoch: 7   train loss:  0.06115978583693504
#     --->>>   episode 39 mini_epoch: 8   train loss:  0.07312804460525513
#     --->>>   episode 39 mini_epoch: 9   train loss:  0.08520574867725372
#     --->>>   episode 39 mini_epoch: 10   train loss:  0.026633355766534805
#     --->>>   episode 39 mini_epoch: 11   train loss:  0.014393321238458157
#     --->>>   episode 39 mini_epoch: 12   train loss:  0.008970160037279129
#     --->>>   episode 39 mini_epoch: 13   train loss:  0.008988442830741405
#     --->>>   episode 39 mini_epoch: 14   train loss:  0.005297412164509296
#     --->>>   episode 39 mini_epoch: 15   train loss:  0.00431419350206852
#     --->>>   episode 39 mini_epoch: 16   train loss:  0.0027164958883076906
#     --->>>   episode 39 mini_epoch: 17   train loss:  0.008652525953948498
#     --->>>   episode 39 mini_epoch: 18   train loss:  0.0024764135014265776
#     --->>>   episode 39 mini_epoch: 19   train loss:  0.0019984503742307425
#     --->>>   episode 39 mini_epoch: 20   train loss:  0.002178712747991085
#     --->>>   episode 39 mini_epoch: 21   train loss:  0.003862928133457899
#     --->>>   episode 39 mini_epoch: 22   train loss:  0.0021119662560522556
#     --->>>   episode 39 mini_epoch: 23   train loss:  0.0009399332338944077
#     --->>>   episode 39 mini_epoch: 24   train loss:  0.003331886837258935
# Generated  Tasks - num_classes: 15, n_shot: 5, n_query: 15
# Traning accuracy:  0.1288888888888889
#     --->>>   episode 40 mini_epoch: 0   train loss:  5.147810459136963
#     --->>>   episode 40 mini_epoch: 1   train loss:  3.2278683185577393
#     --->>>   episode 40 mini_epoch: 2   train loss:  2.7274930477142334
#     --->>>   episode 40 mini_epoch: 3   train loss:  2.5257630348205566
#     --->>>   episode 40 mini_epoch: 4   train loss:  2.551539421081543
#     --->>>   episode 40 mini_epoch: 5   train loss:  2.3804564476013184
#     --->>>   episode 40 mini_epoch: 6   train loss:  2.234135866165161
#     --->>>   episode 40 mini_epoch: 7   train loss:  2.155881881713867
#     --->>>   episode 40 mini_epoch: 8   train loss:  2.056408166885376
#     --->>>   episode 40 mini_epoch: 9   train loss:  2.026390314102173
#     --->>>   episode 40 mini_epoch: 10   train loss:  1.8677102327346802
#     --->>>   episode 40 mini_epoch: 11   train loss:  1.805790662765503
#     --->>>   episode 40 mini_epoch: 12   train loss:  1.6796234846115112
#     --->>>   episode 40 mini_epoch: 13   train loss:  1.6034752130508423
#     --->>>   episode 40 mini_epoch: 14   train loss:  1.5261881351470947
#     --->>>   episode 40 mini_epoch: 15   train loss:  1.4566582441329956
#     --->>>   episode 40 mini_epoch: 16   train loss:  1.4204388856887817
#     --->>>   episode 40 mini_epoch: 17   train loss:  1.2686259746551514
#     --->>>   episode 40 mini_epoch: 18   train loss:  1.2619585990905762
#     --->>>   episode 40 mini_epoch: 19   train loss:  1.1609199047088623
#     --->>>   episode 40 mini_epoch: 20   train loss:  1.1039530038833618
#     --->>>   episode 40 mini_epoch: 21   train loss:  1.0608673095703125
#     --->>>   episode 40 mini_epoch: 22   train loss:  0.9819703102111816
#     --->>>   episode 40 mini_epoch: 23   train loss:  0.9942426085472107
#     --->>>   episode 40 mini_epoch: 24   train loss:  0.9238632321357727
# Generated  Tasks - num_classes: 20, n_shot: 12, n_query: 8
# Traning accuracy:  0.15
#     --->>>   episode 41 mini_epoch: 0   train loss:  2.9601476192474365
#     --->>>   episode 41 mini_epoch: 1   train loss:  2.8506720066070557
#     --->>>   episode 41 mini_epoch: 2   train loss:  2.6430201530456543
#     --->>>   episode 41 mini_epoch: 3   train loss:  2.3759496212005615
#     --->>>   episode 41 mini_epoch: 4   train loss:  2.2258243560791016
#     --->>>   episode 41 mini_epoch: 5   train loss:  2.0313258171081543
#     --->>>   episode 41 mini_epoch: 6   train loss:  1.9804580211639404
#     --->>>   episode 41 mini_epoch: 7   train loss:  1.8701145648956299
#     --->>>   episode 41 mini_epoch: 8   train loss:  1.793562650680542
#     --->>>   episode 41 mini_epoch: 9   train loss:  1.6850332021713257
#     --->>>   episode 41 mini_epoch: 10   train loss:  1.6345603466033936
#     --->>>   episode 41 mini_epoch: 11   train loss:  1.5420042276382446
#     --->>>   episode 41 mini_epoch: 12   train loss:  1.5120365619659424
#     --->>>   episode 41 mini_epoch: 13   train loss:  1.4736430644989014
#     --->>>   episode 41 mini_epoch: 14   train loss:  1.3513588905334473
#     --->>>   episode 41 mini_epoch: 15   train loss:  1.2670843601226807
#     --->>>   episode 41 mini_epoch: 16   train loss:  1.2136284112930298
#     --->>>   episode 41 mini_epoch: 17   train loss:  1.1115878820419312
#     --->>>   episode 41 mini_epoch: 18   train loss:  1.0507255792617798
#     --->>>   episode 41 mini_epoch: 19   train loss:  0.9874536395072937
#     --->>>   episode 41 mini_epoch: 20   train loss:  0.92766273021698
#     --->>>   episode 41 mini_epoch: 21   train loss:  0.9156181216239929
#     --->>>   episode 41 mini_epoch: 22   train loss:  0.8053110837936401
#     --->>>   episode 41 mini_epoch: 23   train loss:  0.779391884803772
#     --->>>   episode 41 mini_epoch: 24   train loss:  0.7380537390708923
# Generated  Tasks - num_classes: 20, n_shot: 9, n_query: 11
